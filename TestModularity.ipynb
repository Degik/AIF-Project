# %%
from startEnv import loadLogic, createGame, printMap

# %%
import os
print(os.getcwd())
# Out:
# /home/davide/myTest/AIF

# %%
prolog = loadLogic()

# %%
env, state, game_map, game = createGame()

# %%
printMap(env, state)
# Out:
# Hello Agent, welcome to NetHack!  You are a neutral human Caveman.
#
#                               ....................
#                               ....................
#                               ....................
#                               ....................
#                               .)..................
#                               ......@.............
#                               ....................
#                               ....................
#                               ....................
#                               ....................
#                               ....................
#                               ....................
#                               ....................
#                               .......%............
#                               ....................
#                               ....................
#                               ....................
# ...

# %%
from startEnv import startSearch
state, _, _, _ = startSearch(env, game_map, prolog)
# Out:
# agent(6,36)
# apple(14,37)

# %%
import time
import matplotlib.pyplot as plt
from IPython import display  # Notice the updated import here

# Assicurati che game abbia le dimensioni corrette prima di eseguire questo.
image = plt.imshow(game[25:350, 475:825])
for i in range(100):  # Corretto da 'in 100' a 'in range(100)'
    time.sleep(0.5)
    state, _, _, _ = startSearch(env, game_map, prolog)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    image.set_data(state["pixel"][25:350, 475:825])
# Out:
# agent(11,36)
# apple(14,37)
