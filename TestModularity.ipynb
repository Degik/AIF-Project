# %%
from startEnv import loadLogic, createGame, printMap

# %%
import os
print(os.getcwd())
# Out:
# /home/davide/myTest/AIF

# %%
prolog = loadLogic()

# %%
env, state, game_map, game = createGame()

# %%
printMap(env, state)
# Out:
# Hello Agent, welcome to NetHack!  You are a lawful human Caveman.
#
#                               ....................
#                               ....................
#                               ....................
#                               ....................
#                               ....................
#                               ....................
#                               ....................
#                               ....................
#                               ....................
#                               ....................
#                               ....................
#                               ....................
#                               ..).................
#                               ....................
#                               ..................@.
#                               ....................
#                               ....................
#                               ....................
#                               .............%......
#                               ....................
# Agent the Troglodyte           St:18/04 Dx:10 Co:15 In:11 Wi:8 Ch:9 Lawful S:0
# Dlvl:1 $:0 HP:16(16) Pw:2(2) AC:8 Xp:1/0

# %%
from startEnv import startSearch
state, _, _, _ = startSearch(env, game_map, prolog)
# Out:
# agent(15,48)
# apple(19,43)

# %%
import time
import matplotlib.pyplot as plt
from IPython import display

image = plt.imshow(game[25:350, 475:825])
for i in range(100):
    time.sleep(0.5)
    state, _, _, _ = startSearch(env, game_map, prolog)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    image.set_data(state["pixel"][25:350, 475:825])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 9
#       7 for i in range(100):  # Corretto da 'in 100' a 'in range(100)'
#       8     time.sleep(0.5)
# ----> 9     state, _, _, _ = startSearch(env, game_map, prolog)
#      10     display.display(plt.gcf())
#      11     display.clear_output(wait=True)
#
# File ~/myTest/AIF/startEnv.py:52, in startSearch(env, game_map, prolog)
#      50 prolog.retractall("apple(_,_)")
#      51 player = utils.get_player_location(game_map)
# ---> 52 target = utils.get_target_location(game_map)
#      53 prolog.assertz(f"agent({player[0]},{player[1]})")
#      54 prolog.assertz(f"apple({target[0]},{target[1]})")
#
# File ~/myTest/AIF/utils.py:16, in get_target_location(game_map, symbol)
#      14 def get_target_location(game_map: np.ndarray, symbol : str = "%") -> Tuple[int, int]:
#      15     x, y = np.where(game_map == ord(symbol))
# ---> 16     return (x[0], y[0])
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
